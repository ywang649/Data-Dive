# %%
import pandas as pd
df=pd.read_csv('market_home_value.csv')
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName BaseDate  \
# 0      102001         0    United States    country       NaN  8/31/24
# 1      394913         1     New York, NY        msa        NY  8/31/24
# 2      753899         2  Los Angeles, CA        msa        CA  8/31/24
# 3      394463         3      Chicago, IL        msa        IL  8/31/24
# 4      394514         4       Dallas, TX        msa        TX  8/31/24
# ..        ...       ...              ...        ...       ...      ...
# 890    753929       935       Zapata, TX        msa        TX  8/31/24
# 891    394743       936    Ketchikan, AK        msa        AK  8/31/24
# 892    753874       937        Craig, CO        msa        CO  8/31/24
# 893    395188       938       Vernon, TX        msa        TX  8/31/24
# 894    394767       939       Lamesa, TX        msa        TX  8/31/24
#
#      9/30/24  11/30/24  8/31/25
# 0        0.1       0.3      1.5
# 1        0.3       0.1     -0.1
# ...

# %%
df_IL=df[df['StateName']=='IL']
df_IL
# Out:
#      RegionID  SizeRank        RegionName RegionType StateName BaseDate  \
# 3      394463         3       Chicago, IL        msa        IL  8/31/24
# 133    394972       136        Peoria, IL        msa        IL  8/31/24
# 141    394520       144     Davenport, IA        msa        IL  8/31/24
# 150    395033       153      Rockford, IL        msa        IL  8/31/24
# 203    394454       209     Champaign, IL        msa        IL  8/31/24
# 213    395114       220   Springfield, IL        msa        IL  8/31/24
# 248    753869       255   Bloomington, IL        msa        IL  8/31/24
# 312    394442       321    Carbondale, IL        msa        IL  8/31/24
# 359    394734       370      Kankakee, IL        msa        IL  8/31/24
# 367    394524       378       Decatur, IL        msa        IL  8/31/24
# 455    395010       468        Quincy, IL        msa        IL  8/31/24
# 459    394516       472      Danville, IL        msa        IL  8/31/24
# ...
